# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/TMDB IMDB Movies Dataset")

# %%
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                                         genres  \
# ...

# %%
df.shape
# Out:
# (434437, 29)

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'tconst', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords', 'directors', 'writers', 'averageRating', 'numVotes',
#        'cast'],
#       dtype='object')

# %%
df[['original_title' , 'title']].head()
# Out:
#     original_title            title
# 0        Inception        Inception
# 1     Interstellar     Interstellar
# 2  The Dark Knight  The Dark Knight
# 3           Avatar           Avatar
# 4     The Avengers     The Avengers

# %% [markdown]
# #lets drop the column

# %%
columns_to_drop = df[['id', 'backdrop_path' , 'homepage' , 'tconst' , 'original_title', 'overview', 'poster_path', 'tagline']]

# %%
df.drop(columns = columns_to_drop , axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'budget', 'original_language',
#        'popularity', 'genres', 'production_companies', 'production_countries',
#        'spoken_languages', 'keywords', 'directors', 'writers', 'averageRating',
#        'numVotes', 'cast'],
#       dtype='object')

# %%
df.drop(columns = 'keywords' , axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'budget', 'original_language',
#        'popularity', 'genres', 'production_companies', 'production_countries',
#        'spoken_languages', 'directors', 'writers', 'averageRating', 'numVotes',
#        'cast'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434437 entries, 0 to 434436
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   title                 434437 non-null  object
#  1   vote_average          434437 non-null  float64
#  2   vote_count            434437 non-null  int64
#  3   status                434437 non-null  object
#  4   release_date          415357 non-null  object
#  5   revenue               434437 non-null  int64
#  6   runtime               434437 non-null  int64
#  7   adult                 434437 non-null  bool
#  8   budget                434437 non-null  int64
#  9   original_language     434437 non-null  object
#  10  popularity            434437 non-null  float64
#  11  genres                356256 non-null  object
#  12  production_companies  262412 non-null  object
#  13  production_countries  321649 non-null  object
# ...

# %%
df['release_date'].head(2)
# Out:
# 0    2010-07-15
# 1    2014-11-05
# Name: release_date, dtype: object

# %%
#df['year'] = df['release_date'].dt.year

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434437 entries, 0 to 434436
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   title                 434437 non-null  object
#  1   vote_average          434437 non-null  float64
#  2   vote_count            434437 non-null  int64
#  3   status                434437 non-null  object
#  4   release_date          415357 non-null  datetime64[ns]
#  5   revenue               434437 non-null  int64
#  6   runtime               434437 non-null  int64
#  7   adult                 434437 non-null  bool
#  8   budget                434437 non-null  int64
#  9   original_language     434437 non-null  object
#  10  popularity            434437 non-null  float64
#  11  genres                356256 non-null  object
#  12  production_companies  262412 non-null  object
#  13  production_countries  321649 non-null  object
# ...

# %%
#df['year'] = df['release_date'].dt.year.astype('Int64')

# %%
#df['month'] = df['release_date'].dt.month.astype('Int64')

# %%
#df['Day_Name'] = df['release_date'].dt.day_name()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434437 entries, 0 to 434436
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   title                 434437 non-null  object
#  1   vote_average          434437 non-null  float64
#  2   vote_count            434437 non-null  int64
#  3   status                434437 non-null  object
#  4   release_date          415357 non-null  datetime64[ns]
#  5   revenue               434437 non-null  int64
#  6   runtime               434437 non-null  int64
#  7   adult                 434437 non-null  bool
#  8   budget                434437 non-null  int64
#  9   original_language     434437 non-null  object
#  10  popularity            434437 non-null  float64
#  11  genres                356256 non-null  object
#  12  production_companies  262412 non-null  object
#  13  production_countries  321649 non-null  object
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# production_companies    172025
# production_countries    112788
# spoken_languages        102419
# genres                   78181
# cast                     68578
# writers                  66528
# release_date             19080
# directors                10263
# numVotes                     0
# averageRating                0
# title                        0
# vote_average                 0
# original_language            0
# budget                       0
# adult                        0
# runtime                      0
# revenue                      0
# status                       0
# vote_count                   0
# popularity                   0
# dtype: int64

# %%
df.dropna(subset = ['release_date'] , inplace =True)

# %%
df['release_date'].isnull().sum()
# Out:
# 0

# %%
df['year'] = df['release_date'].dt.year.astype('int64')
df['month'] = df['release_date'].dt.month.astype('int64')
df['Day_Name'] = df['release_date'].dt.day_name()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 415357 entries, 0 to 434436
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   title                 415357 non-null  object
#  1   vote_average          415357 non-null  float64
#  2   vote_count            415357 non-null  int64
#  3   status                415357 non-null  object
#  4   release_date          415357 non-null  datetime64[ns]
#  5   revenue               415357 non-null  int64
#  6   runtime               415357 non-null  int64
#  7   adult                 415357 non-null  bool
#  8   budget                415357 non-null  int64
#  9   original_language     415357 non-null  object
#  10  popularity            415357 non-null  float64
#  11  genres                351755 non-null  object
#  12  production_companies  260271 non-null  object
#  13  production_countries  319236 non-null  object
# ...

# %%
col_to_replace = ['production_companies', 'production_countries','spoken_languages',
'genres','cast','writers','release_date','Day_Name','year','month','directors']

# %%
for i in col_to_replace:
  df[i] = df[i].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# original_language       0
# popularity              0
# genres                  0
# production_companies    0
# production_countries    0
# spoken_languages        0
# directors               0
# writers                 0
# averageRating           0
# numVotes                0
# cast                    0
# year                    0
# month                   0
# Day_Name                0
# dtype: int64

# %%
df.head()
# Out:
#              title  vote_average  vote_count    status release_date  \
# 0        Inception         8.364       34495  Released   2010-07-15
# 1     Interstellar         8.417       32571  Released   2014-11-05
# 2  The Dark Knight         8.512       30619  Released   2008-07-16
# 3           Avatar         7.573       29815  Released   2009-12-15
# 4     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult     budget original_language  ...  \
# 0   825532764      148  False  160000000                en  ...
# 1   701729206      169  False  165000000                en  ...
# 2  1004558444      152  False  185000000                en  ...
# 3  2923706026      162  False  237000000                en  ...
# 4  1518815515      143  False  220000000                en  ...
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# ...

# %%
df['genres'].head()
# Out:
# 0             Action, Science Fiction, Adventure
# 1              Adventure, Drama, Science Fiction
# 2                 Drama, Action, Crime, Thriller
# 3    Action, Adventure, Fantasy, Science Fiction
# 4             Science Fiction, Action, Adventure
# Name: genres, dtype: object

# %%
df['genres'] = df['genres'].astype(str).apply(lambda x : x.split(",")[0].strip())   # STRIP eliminate extra spaces

# %%
df['genres'].head()
# Out:
# 0             Action
# 1          Adventure
# 2              Drama
# 3             Action
# 4    Science Fiction
# Name: genres, dtype: object

# %%
df.shape
# Out:
# (415357, 23)

# %% [markdown]
# # Year wise movies

# %%
df['year'].value_counts().sort_index(ascending=False).head(10)
# Out:
# year
# 2029        1
# 2027        2
# 2025        2
# 2024     2561
# 2023     9497
# 2022    11929
# 2021    11565
# 2020    11523
# 2019    14058
# 2018    13750
# Name: count, dtype: int64

# %%
df['status'].unique()
# Out:
# array(['Released', 'In Production', 'Post Production', 'Planned',
#        'Canceled'], dtype=object)

# %%
df[df['year'].isin([2025,2026,2029])]
# Out:
#                                           title  vote_average  vote_count  \
# 293538                  Desmontando un elefante           0.0           0
# 302142  Indiana Jones: Return of Elsa Schneider           0.0           0
# 372636                                      EFC           0.0           0
#
#                  status release_date  revenue  runtime  adult  budget  \
# 293538          Planned   2025-01-10        0        0  False       0
# 302142         Released   2029-10-13        0       16  False       0
# 372636  Post Production   2025-03-06        0       90  False       0
#
#        original_language  ...  production_countries spoken_languages  \
# 293538                es  ...         Spain, France          Spanish
# 302142                en  ...               Unknown          Unknown
# 372636                en  ...                Canada          English
#
#                          directors  \
# 293538            Aitor Echeverría
# ...

# %%
df = df[~df['year'].isin([2025,2027,2029])]

# %%
df['year'].value_counts().sort_index(ascending=False).head(10)
# Out:
# year
# 2024     2561
# 2023     9497
# 2022    11929
# 2021    11565
# 2020    11523
# 2019    14058
# 2018    13750
# 2017    13793
# 2016    12940
# 2015    12786
# Name: count, dtype: int64

# %%
movies_per_year =df['year'].value_counts().sort_index(ascending=False)

# %%
sns.lineplot(x=movies_per_year.index, y=movies_per_year.values)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# #top 10 average rating movies

# %%
top_to_avg_movies = df.sort_values(by="averageRating", ascending=False).head(10)

# %%
top_to_avg_movies[["title", "averageRating"]]
# Out:
#                             title  averageRating
# 285189              A Dire Strait           10.0
# 290812     Twin Cities Pride 2020           10.0
# 395992  Postcards from the Orient           10.0
# 273437                   His Home           10.0
# 174723                   Bereaved           10.0
# 247393           Dispatched Dream           10.0
# 267262                   Botswana           10.0
# 298949      Tiki Bar Funeral Home           10.0
# 178831      The Guards Themselves           10.0
# 240296             ¿Somos Pobres?           10.0

# %%
df[['vote_average', 'averageRating', 'vote_count', 'numVotes']].head()
# Out:
#    vote_average  averageRating  vote_count  numVotes
# 0         8.364            8.8       34495   2684780
# 1         8.417            8.7       32571   2346977
# 2         8.512            9.0       30619   3022443
# 3         7.573            7.9       29815   1431576
# 4         7.710            8.0       29166   1508926

# %% [markdown]
# #vote_average is TMdb score and average rating is Internet Movies Database score
# #vote_count is TMdb votes and numVote is IMdb
# #average

# %%
df = df.rename( columns= {'vote_average':"TMDB_rating", 'averageRating':"IMDB_rating", 'vote_count':"TMDB_votes", 'numVotes':"IMDB_votes"})

# %%
df['spoken_languages'].unique()
# Out:
# array(['English, French, Japanese, Swahili', 'English',
#        'English, Mandarin', ..., 'Bulgarian, English, German, Russian',
#        'Mandarin, English, Greek', 'Kurdish, Persian, Spanish'],
#       dtype=object)

# %%
df['original_language'].unique()
# Out:
# array(['en', 'ko', 'fr', 'ja', 'it', 'es', 'pl', 'pt', 'hi', 'tr', 'da',
#        'de', 'cn', 'id', 'zh', 'sv', 'el', 'ru', 'sr', 'fa', 'th', 'ar',
#        'no', 'nb', 'fi', 'te', 'la', 'nl', 'hu', 'he', 'is', 'ro', 'gl',
#        'uk', 'eu', 'et', 'bs', 'bn', 'xx', 'sh', 'km', 'cs', 'tn', 'ml',
#        'mk', 'ga', 'hy', 'ku', 'ka', 'ta', 'kn', 'tl', 'vi', 'ca', 'dz',
#        'sw', 'kk', 'wo', 'sk', 'mi', 'lv', 'bo', 'ps', 'mn', 'lt', 'ur',
#        'sl', 'sc', 'af', 'hr', 'iu', 'se', 'ms', 'bm', 'mr', 'bg', 'cy',
#        'am', 'lo', 'xh', 'qu', 'yi', 'yo', 'pa', 'sq', 'eo', 'gu', 'zu',
#        'st', 'ne', 'ak', 'mt', 'rw', 'ln', 'ay', 'as', 'si', 'mo', 'ff',
#        'so', 'ky', 'ik', 'az', 'kl', 'jv', 'fo', 'li', 'sn', 'ks', 'su',
#        'my', 'tg', 'ht', 'lb', 'sa', 'sm', 'rm', 'tk', 'ha', 'fy', 'ab',
#        'ny', 'or', 'gd', 'om', 'be', 'uz', 'cr', 'mg', 'co', 'mh', 'tw',
#        'gn', 'nv', 'os', 'tt', 'ig', 'ug', 'sg', 'nd', 'dv', 'kw', 'lg',
# ...
